# %%
import pandas as pd
url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"
sharkattacks = pd.read_excel(url)
display(sharkattacks.head(3))
sharkattacks.shape
display(sharkattacks.columns)
# Out:
#           Date    Year        Type    Country       State            Location  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA  Queensland       Bargara Beach
# 1  04 Mar 2024  2024.0  Unprovoked        USA      Hawaii  Old Man's, Waikiki
# 2  02 Mar-2024  2024.0  Unprovoked        USA      Hawaii      Rainbows, Oahu
#
#    Activity            Name Sex  Age  \
# 0  Swimming  Brooklyn Sauer   F   13
# 1   Surfing   Matthew White   M  NaN
# 2  Swimming             NaN   F   11
#
#                                      Injury Unnamed: 11   Time  \
# 0  Minor injuries to back, abdomen and legs         NaN  16h00
# 1            No injury, shark bit surfboard           N    NaN
# 2                  Lacerations to left foot           N  13h30
#
#          Species                      Source  pdf href formula href  \
# 0     Tiger shark      Yahoo News, 3/15/2024  NaN          NaN  NaN
# 1  Tiger shark 8'          Surfer, 3/6/2024F  NaN          NaN  NaN
# 2  3' to 4' shark  Hawaii News Now, 3/4/2024  NaN          NaN  NaN
#
#   Case Number Case Number.1  original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN             NaN         NaN         NaN
# 1         NaN           NaN             NaN         NaN         NaN
# 2         NaN           NaN             NaN         NaN         NaN
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Unnamed: 11', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
##Standardizing column names
sharkattacks.columns = [x.strip() for x in sharkattacks.columns]
sharkattacks.columns = [x.lower().replace(' ', '_') for x in sharkattacks.columns]
sharkattacks = sharkattacks.applymap(lambda x:x.lower() if isinstance(x,str) else x)

sharkattacks.columns
# Out:
# Index(['date', 'year', 'type', 'country', 'state', 'location', 'activity',
#        'name', 'sex', 'age', 'injury', 'unnamed:_11', 'time', 'species',
#        'source', 'pdf', 'href_formula', 'href', 'case_number', 'case_number.1',
#        'original_order', 'unnamed:_21', 'unnamed:_22'],
#       dtype='object')

# %%
##Cleaning "YEAR" column
sharkattacks["year"].isnull().sum()
year_mode=int(sharkattacks["year"].mode())
sharkattacks["year"].fillna(year_mode,inplace=True)
sharkattacks["year"].isnull().sum()
sharkattacks["year"].unique()
sharkattacks["year"]=sharkattacks["year"].map({x:year_mode if x==0 or x==5 or x==77 or x==1000 else x for x in sharkattacks["year"]})
sharkattacks["year"]=sharkattacks["year"].map({x:year_mode if x==1500 else x for x in sharkattacks["year"]})
sharkattacks["year"].value_counts()
sharkattacks["year"] = sharkattacks["year"].astype(int)
# Out:
# <ipython-input-109-903de30dd422>:3: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   year_mode=int(sharkattacks["year"].mode())

# %%
##Cleaning "COUNTRY" column
sharkattacks['country'] = sharkattacks['country'].astype(str)
sharkattacks['country'] = sharkattacks['country'].map(lambda x: x.upper())
sharkattacks["country"] = sharkattacks["country"].fillna("UNKNOWN")
sharkattacks["country"] = sharkattacks["country"].str.strip()
sharkattacks["country"] = sharkattacks["country"].replace({"UKNOWN": "UNKNOWN",'nan':"UNKNOWN",'NAN' : "UNKNOWN"})
sharkattacks["country"].nunique()
# Out:
# 210

# %%
##Cleaning "LOCATION" column
sharkattacks["location"].isnull().sum()
sharkattacks["location"].fillna("UNKNOWN",inplace=True)
sharkattacks["location"].isnull().sum()
sharkattacks["location"]=sharkattacks["location"].apply(lambda x:x.title())

# %%
##Cleaning "ACTIVITY" column
sharkattacks['activity'] = sharkattacks['activity'].astype(str)
sharkattacks['activity'] = sharkattacks['activity'].map(lambda x: x.title())
sharkattacks["activity"] = sharkattacks["activity"].fillna("UNKNOWN")
sharkattacks["activity"] = sharkattacks["activity"].str.strip()
sharkattacks["activity"] = sharkattacks["activity"].dropna().apply(lambda x: "Fishing" if 'fish' in x else x)
sharkattacks["activity"] = sharkattacks["activity"].dropna().apply(lambda x: "Fishing" if 'Fishing' in x else x)
sharkattacks["activity"] = sharkattacks["activity"].dropna().apply(lambda x: "Fishing" if 'Fish' in x else x)
sharkattacks["activity"] = sharkattacks["activity"].dropna().apply(lambda x: "Fishing" if 'fishing' in x else x)
sharkattacks["activity"] = sharkattacks["activity"].replace({'NAN' : "UNKNOWN", 'Nan' : "UNKNOWN"})

# %%
##Cleaning "SEX" column
sharkattacks['sex'] = sharkattacks['sex'].map({'n': 'm', 'ill': 'm', 'm x 2':'.', '.': '.', 'm': 'm', 'f': 'f'})
sharkattacks['sex'].fillna('m', inplace=True)
sharkattacks= sharkattacks.drop(index=3580)
sharkattacks= sharkattacks.drop(index=6069)
sharkattacks= sharkattacks.drop(index=5568)

# %%
##Cleaning "STATE" column
sharkattacks['state'] = sharkattacks['state'].astype(str)
sharkattacks['state'] = sharkattacks['state'].map(lambda x: x.title())
sharkattacks["state"] = sharkattacks["state"].fillna("UNKNOWN")
sharkattacks["state"] = sharkattacks["state"].str.strip()
sharkattacks["state"] = sharkattacks["state"].replace({"UKNOWN": "UNKNOWN",'nan':"UNKNOWN",'NAN' : "UNKNOWN"})

# %%
##Cleaning "TYPE" column:
sharkattacks["type"].isnull().sum()
sharkattacks["type"].fillna("unidentified", inplace = True)
sharkattacks["type"] = sharkattacks["type"].apply(lambda x: x.strip())
sharkattacks ["type"] = sharkattacks ["type"].replace("?","UNKNOWN")
sharkattacks ["type"] = sharkattacks ["type"].replace("boat","UNKNOWN")

# %%
##Cleaning "NAME" column:
sharkattacks["name"].isnull().sum()
sharkattacks["name"].fillna("UNKNOWN",inplace=True)
sharkattacks["name"].isnull().sum()
sharkattacks["name"].value_counts()
sharkattacks["name"]=sharkattacks["name"].replace("2 males","two males")
sharkattacks["name"]=sharkattacks["name"].apply(lambda x:x.title())

# %%
##Cleaning "INJURY" column:
sharkattacks["injury"].isnull().sum()
sharkattacks["injury"].fillna("UNKNOWN", inplace = True)
sharkattacks["injury"].isnull().sum()
sharkattacks["injury"] = sharkattacks["injury"].apply(lambda x: x.strip())

# %%
##Cleaning "SOURCE" column:
sharkattacks['source'] = sharkattacks['source'].astype(str)
sharkattacks["source"].isnull().sum()
sharkattacks["source"].fillna("UNKNOWN", inplace = True)
sharkattacks["source"].isnull().sum()
sharkattacks["source"] = sharkattacks["source"].apply(lambda x: x.strip())

# %%
##Cleaning "AGE" column:
sharkattacks['age'] = sharkattacks['age'].map({x: str(x).strip(' ') for x in sharkattacks['age']})
sharkattacks['age'] = sharkattacks['age'].map({x:'UNKNOWN' if len(x)>2 else x for x in sharkattacks['age']})
sharkattacks['age'] = sharkattacks['age'].map({x:'UNKNOWN' if not(str(x).isdigit()) else x for x in sharkattacks['age']})
sharkattacks['age'] = sharkattacks['age'].map({x: 28 if x == 'UNKNOWN' else x for x in sharkattacks['age']})
sharkattacks['age'] = sharkattacks['age'].map({x: int(x) if isinstance(x,str) else x for x in sharkattacks['age']})

# %%
##Dropping weird columns:
sharkattacks.drop(columns=["unnamed:_11","unnamed:_21","unnamed:_22","pdf","href_formula","href","case_number","case_number.1","original_order"], inplace=True)

# %%
sharkattacks.head(3)
# Out:
#           date  year        type    country       state            location  \
# 0  15 mar 2024  2024  unprovoked  AUSTRALIA  Queensland       Bargara Beach
# 1  04 mar 2024  2024  unprovoked        USA      Hawaii  Old Man'S, Waikiki
# 2  02 mar-2024  2024  unprovoked        USA      Hawaii      Rainbows, Oahu
#
#    activity            name sex  age  \
# 0  Swimming  Brooklyn Sauer   f   13
# 1   Surfing   Matthew White   m   28
# 2  Swimming         Unknown   f   11
#
#                                      injury   time         species  \
# 0  minor injuries to back, abdomen and legs  16h00     tiger shark
# 1            no injury, shark bit surfboard    NaN  tiger shark 8'
# 2                  lacerations to left foot  13h30  3' to 4' shark
#
#                       source
# 0      yahoo news, 3/15/2024
# 1          surfer, 3/6/2024f
# 2  hawaii news now, 3/4/2024

# %%
### Printing unique values for all columns to check if the dataset is as clean as possible

for column in sharkattacks.columns:
    unique_values = sharkattacks[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print()
# Out:
# Unique values in column 'date':
# ['15 mar 2024' '04 mar 2024' '02 mar-2024' ... '1883-1889' '1845-1853' nan]
#
# Unique values in column 'year':
# [2024 2023 2022 2021 2020 2019 2018 2017 2015 2016 2014 2013 2012 2011
#  2010 2009 2008 2007 2006 2005 2004 2003 2002 2001 2000 1999 1998 1997
#  1996 1995 1984 1994 1993 1992 1991 1990 1989 1969 1988 1987 1986 1985
#  1983 1982 1981 1980 1979 1978 1977 1976 1975 1974 1973 1972 1971 1970
#  1968 1967 1966 1965 1964 1963 1962 1961 1960 1959 1958 1957 1956 1955
#  1954 1953 1952 1951 1950 1949 1948 1848 1947 1946 1945 1944 1943 1942
#  1941 1940 1939 1938 1937 1936 1935 1934 1933 1932 1931 1930 1929 1928
#  1927 1926 1925 1924 1923 1922 1921 1920 1919 1918 1917 1916 1915 1914
#  1913 1912 1911 1910 1909 1908 1907 1906 1905 1904 1903 1902 1901 1900
#  1899 1898 1897 1896 1895 1894 1893 1892 1891 1890 1889 1888 1887 1886
#  1885 1884 1883 1882 1881 1880 1879 1878 1877 1876 1875 1874 1873 1872
#  1871 1870 1869 1868 1867 1866 1865 1864 1863 1862 1861 1860 1859 1858
#  1857 1856 1855 1853 1852 1851 1850 1849 1847 1846 1845 1844 1842 1841
#  1840 1839 1837 1836 1835 1834 1832 1831 1830 1829 1828 1827 1826 1825
#  1823 1822 1819 1818 1817 1816 1815 1812 1811 1810 1808 1807 1805 1804
#  1803 1802 1801 1800 1797 1792 1791 1788 1787 1786 1785 1784 1783 1780
#  1779 1776 1771 1767 1764 1758 1753 1751 1749 1755 1748 1742 1738 1733
#  1723 1721 1703 1700 1642 1691 1640 1638 1637 1617 1595 1580 1555 1554
#  1543 1518]
#
# Unique values in column 'type':
# ['unprovoked' 'provoked' 'questionable' 'watercraft' 'sea disaster'
#  'unidentified' 'UNKNOWN' 'unconfirmed' 'unverified' 'invalid'
#  'under investigation']
#
# Unique values in column 'country':
# ['AUSTRALIA' 'USA' 'INDIA' 'TRINIDAD' 'BAHAMAS' 'SOUTH AFRICA' 'MEXICO'
#  'NEW ZEALAND' 'EGYPT' 'BELIZE' 'PHILIPPINES' 'CORAL SEA' 'SPAIN'
#  'PORTUGAL' 'SAMOA' 'COLOMBIA' 'ECUADOR' 'FRENCH POLYNESIA'
#  'NEW CALEDONIA' 'TURKS AND CAICOS' 'CUBA' 'BRAZIL' 'SEYCHELLES'
#  'ARGENTINA' 'FIJI' 'MALDIVES' 'ENGLAND' 'JAPAN' 'INDONESIA' 'JAMAICA'
#  'THAILAND' 'COLUMBIA' 'COSTA RICA' 'BRITISH OVERSEAS TERRITORY' 'CANADA'
#  'JORDAN' 'ST KITTS / NEVIS' 'ST MARTIN' 'PAPUA NEW GUINEA'
#  'REUNION ISLAND' 'ISRAEL' 'CHINA' 'IRELAND' 'ITALY' 'MALAYSIA' 'LIBYA'
#  'UNKNOWN' 'MAURITIUS' 'SOLOMON ISLANDS'
#  'ST HELENA, BRITISH OVERSEAS TERRITORY' 'COMOROS' 'REUNION'
#  'UNITED KINGDOM' 'UNITED ARAB EMIRATES' 'CAPE VERDE' 'DOMINICAN REPUBLIC'
#  'CAYMAN ISLANDS' 'ARUBA' 'MOZAMBIQUE' 'PUERTO RICO' 'ATLANTIC OCEAN'
#  'GREECE' 'ST. MARTIN' 'FRANCE' 'TRINIDAD & TOBAGO' 'KIRIBATI'
#  'DIEGO GARCIA' 'TAIWAN' 'PALESTINIAN TERRITORIES' 'GUAM' 'NIGERIA'
#  'TONGA' 'SCOTLAND' 'CROATIA' 'SAUDI ARABIA' 'CHILE' 'ANTIGUA' 'KENYA'
#  'RUSSIA' 'TURKS & CAICOS' 'UNITED ARAB EMIRATES (UAE)' 'AZORES'
#  'SOUTH KOREA' 'MALTA' 'VIETNAM' 'MADAGASCAR' 'PANAMA' 'SOMALIA' 'NEVIS'
#  'BRITISH VIRGIN ISLANDS' 'NORWAY' 'SENEGAL' 'YEMEN' 'GULF OF ADEN'
#  'SIERRA LEONE' 'ST. MAARTIN' 'GRAND CAYMAN' 'LIBERIA' 'VANUATU'
#  'HONDURAS' 'VENEZUELA' 'SRI LANKA' 'URUGUAY' 'MICRONESIA' 'CARIBBEAN SEA'
#  'OKINAWA' 'TANZANIA' 'MARSHALL ISLANDS' 'EGYPT / ISRAEL'
#  'NORTHERN ARABIAN SEA' 'HONG KONG' 'EL SALVADOR' 'ANGOLA' 'BERMUDA'
#  'MONTENEGRO' 'IRAN' 'TUNISIA' 'NAMIBIA' 'NORTH ATLANTIC OCEAN'
#  'SOUTH CHINA SEA' 'BANGLADESH' 'PALAU' 'WESTERN SAMOA' 'PACIFIC OCEAN'
#  'BRITISH ISLES' 'GRENADA' 'IRAQ' 'TURKEY' 'SINGAPORE' 'NEW BRITAIN'
#  'SUDAN' 'JOHNSTON ISLAND' 'SOUTH PACIFIC OCEAN' 'NEW GUINEA' 'RED SEA'
#  'NORTH PACIFIC OCEAN' 'FEDERATED STATES OF MICRONESIA'
#  'MID ATLANTIC OCEAN' 'ADMIRALTY ISLANDS' 'BRITISH WEST INDIES'
#  'SOUTH ATLANTIC OCEAN' 'PERSIAN GULF' 'RED SEA / INDIAN OCEAN'
#  'NORTH SEA' 'NICARAGUA' 'MALDIVE ISLANDS' 'AMERICAN SAMOA'
#  'ANDAMAN / NICOBAR ISLANDAS' 'GABON' 'MAYOTTE' 'THE BALKANS' 'SUDAN?'
#  'MARTINIQUE' 'INDIAN OCEAN' 'GUATEMALA' 'NETHERLANDS ANTILLES'
#  'NORTHERN MARIANA ISLANDS' 'IRAN / IRAQ' 'JAVA' 'CENTRAL PACIFIC'
#  'SOLOMON ISLANDS / VANUATU' 'SOUTHWEST PACIFIC OCEAN' 'BAY OF BENGAL'
#  'MID-PACIFC OCEAN' 'SLOVENIA' 'CURACAO' 'ICELAND' 'ITALY / CROATIA'
#  'BARBADOS' 'MONACO' 'GUYANA' 'HAITI' 'SAN DOMINGO' 'KUWAIT'
#  'FALKLAND ISLANDS' 'CRETE' 'CYPRUS' 'WEST INDIES' 'BURMA' 'LEBANON'
#  'PARAGUAY' 'BRITISH NEW GUINEA' 'CEYLON' 'OCEAN' 'GEORGIA' 'SYRIA'
#  'TUVALU' 'INDIAN OCEAN?' 'GUINEA' 'ANDAMAN ISLANDS'
#  'EQUATORIAL GUINEA / CAMEROON' 'COOK ISLANDS' 'TOBAGO' 'PERU' 'AFRICA'
#  'ALGERIA' 'COAST OF AFRICA' 'TASMAN SEA' 'GHANA' 'GREENLAND'
#  'MEDITERRANEAN SEA' 'SWEDEN' 'ROATAN' 'BETWEEN PORTUGAL & INDIA'
#  'DJIBOUTI' 'BAHREIN' 'KOREA' 'RED SEA?' 'ASIA?' 'CEYLON (SRI LANKA)']
#
# Unique values in column 'state':
# ['Queensland' 'Hawaii' 'Western Australia' 'Maharashtra' 'Nan'
#  'New  South Wales' 'Paradise Island' 'South Australia'
#  'Eastern Cape Province' 'Sonora' 'New South Wales' 'South Island'
#  'Guerrero' 'New Providence   Isoad' 'Jalisco' 'Grand  Bahama Island'
#  'Florida' 'Westerm Australia' 'North Island' 'Southern Red Sea'
#  'Quintana Roo' 'Belize District' 'California' 'South Carolina'
#  'South Sinai' 'Bolinao' 'North Carolina' 'Valencia' 'Norte'
#  "Savai'I Island" 'New York' 'San Andrés Island' 'Galapagos Islands'
#  'Red Sea Protectorate' 'Freeport' 'Tahiti' 'Poum' 'Providenciales Island'
#  'Lucayan Lucayan Archipelago' 'New Jersey' 'Mayabeque'
#  'Easten Cape Province' 'Artemisa' 'Pernambuco' 'Praslin Island'
#  'South Province' 'Patagonia' 'Taveuni Island' 'Gulf Of California'
#  'Vaavu Atoll' 'Knz' 'New South Ales' 'Samoa' 'Texas' 'Louisiana'
#  'Mississippi' 'Western  Australia' 'Victoria' 'Western Cape Province'
#  'Cornwall' 'Noirth Carolina' 'Okinawa' 'Bali'
#  'Hurghada, Red Sea Governorate' 'Ambergris Cay' 'Bora Bora' 'Georgia'
#  'Phuket' 'Alabama' 'Kzn' 'Isla De San Andres' 'Guanacoste'
#  'Kwazulu-Natal' 'São Paulo.' 'Turks And Caicos' 'Nova Scotia' 'Maryland'
#  'Chanthaburi Province' 'Bahamas' 'Galapagos' 'Aqaba' 'West Sussex'
#  'Nouville' 'Ambergris Key' 'Westmoreland Parish' 'Marquesas'
#  'Loyalty Islands' 'Maui' 'The Narrows' 'Raa Atoll' 'Oregon'
#  'Grand Bahama Island' 'Franklin County, Florida' 'Virgin Islands'
#  'Tasmania' 'Tuamotu Islands' 'Maine' 'Exumas' 'Delaware' 'Abaco Islands'
#  'Muang District Of Satun Province,' 'Canary Islands' 'Vanua Levu'
#  'Southland' 'Phang Nga Province' 'Praslin' 'Central Province' 'Holquin'
#  'Moorea' 'Baja' 'Saint-Gilles' 'Guam' 'Northern Territory'
#  'Cayman Islands' 'Rhode Island' 'Chatham Islands' 'Quinta Roo'
#  'Lucayan Archipelago' 'Bélep Islands' 'Noumea' 'Fernando De Noronha'
#  'Liaoning Province' 'Upolo' 'St. Marys Parish' 'Massachusetts'
#  'County Cork' 'Chieti, Province' 'Guizhou Province'
#  'San Andres And Providencia Archipelago' 'The Exuma Cays' 'Colima'
#  'Hua Hin' 'Cocos Island' 'Alifu Alifu Atoll' 'New Providence' 'Alagoas'
#  'Boi Island, Victoria' 'Sepang' 'Holquin Province' 'Pamplemousses'
#  'Upolu Island' 'Shizuoka Prefecture' 'Castellón'
#  'New Providence District' '40 Miles Off Grand Bahama Island'
#  'Ascension Island' 'Majorca' 'Washington' 'Tabasco' 'Anjouan'
#  'Ibiza Island' 'South Devon' 'Sharjah,' 'Baja California Sur' 'Saint-Leu'
#  'Luzon Island' 'Tamaulipas' 'Saint-Andre' 'Bimini' 'Tuamotos'
#  'North Province' 'New Providence Island' 'Alicante Province' 'Hong Kong'
#  'Kochi Prefecture' 'Isla Providencia' 'Suez' 'Grand Terre'
#  'Boa Vista Island' 'Santa Catarina State' 'Altagracia Province'
#  'Grand Cayman' 'Balneário Camboriú' 'Fujairah Emirate'
#  'Grand Canary Island' 'Inhambane Province' 'Alicante' 'Guanacaste'
#  'Le Port' 'Rangiroa' 'Saint-Gilles-Les-Bains' 'Sardinia' 'Sinaloa'
#  'Central Tuamotu' 'D’Étang-Salé' 'Granada'
#  'Cargados Carajos Shoals (St. Brandon)' 'Catalonia' 'West End'
#  'Atsumi Peninsula' 'Palmyra Atoll' 'Wallis And Futuna'
#  'Baie De Sainte-Marie' 'Society Islands' 'Trinidad' 'Okinawa Prefecture'
#  '740 Miles Se Of Tarawa Atoll' 'Southern District' 'Bay Of Biscay'
#  'Exuma Islands' 'Saint-Paul' 'Taitung' 'Kingston Parish'
#  'Santa Cruz Island' 'Tuamotus' 'Eleuthera' 'St. Catherine' 'Palawan'
#  'Mercury Islands' 'Delta' "Vava'U" 'Inner Hebrides' 'Saint Leu'
#  'Trois-Bassins' 'British Colombia' 'Saint-Benoit' 'Tabuk Province'
#  'Antofagasta Province' "St John'S" 'Santa Elena' 'East New Britain'
#  'Bois-Blanc' 'Moray' 'Puerto Rico' 'Samaná Province' 'Coast Province'
#  'Primorsky Krai' 'Peter The Great Bay, Khasan, Primorsky Krai (Far East)'
#  'Telyakovsky Bay, Khasan,  Primorsky Krai (Far East)' 'Sucre'
#  'Middle Caicos' 'Caicos Bank' 'San Andrés Archipelago' 'Kedah'
#  'Umm Al Qaywayan Province' 'Vitu Levu' 'South Sinai Peninsula'
#  'Saint Gilles' 'Virginia' "Ha'Api" 'Western Province' 'Jeju Province'
#  'Binh Dinh Province' 'Antsiranana Province' 'Sinai Peninsula'
#  'Off Vanua Levu' 'Merizo' 'Rio Grande Do Sul' 'Dubai' 'Torres Strait'
#  'Eastern Province' 'Eastern Cape  Province' 'Maputo Province' 'Bocas'
#  'Fife' 'Devon' 'Makira-Ulawa Province' 'Mombasa' 'Catalunya'
#  'St. Johns Reef' 'Off Green Island' 'North Region' 'Batangas Province'
#  'Strait Of Malacca' 'Guantanamo Province' 'Maranhão' 'Red Sea'
#  'Batanes Provine' 'Luzon' 'Split-Dalmatia Count,' 'North Devon'
#  'Us Virgin Islands' 'San Carlos' 'Cabo San Lucas' 'Sussex' 'Bahia'
#  'Easter Ross' 'Guerro' 'Yasawa Islands' 'Northern Bahamas' 'Tokyo Bay'
#  'Baja California' 'Green Bay' 'Marovo Lagoon'
#  'Territory Of Cocos (Keeling) Islands' 'Oslo Fjord' 'Kent' 'Bird Island'
#  'Providenciales' 'Bimini Islands' 'Muhafazat Hadramawt' 'Cook Islans'
#  'Surigao Del Norte' 'Between Somalia & Yemen' 'Ambergris Caye'
#  'Saint-Pierre' 'Kentucky' 'Andros Islands' 'Western Area'
#  '300 Miles From Antigua' '800 Miles From Land'
#  '600 Nm West Of The Canary Islands' 'Simpson Bay' 'East Wall'
#  'Inner Islands' 'Shanghai' 'Malampa Province'
#  "South Ch'Ungch'Ong Province" 'Bay Islands' 'New Mexico'
#  'Santa Isabel Province' 'Santiago De Cuba Province' 'Camaguey Province'
#  'Conservatória District' 'Kuril Islands In The Pacific'
#  'Wakayama Prefecture' "Nuku'Alofa" 'Saint-Benoît'
#  'South Island, Near Karitane North Of Dunedin' 'Rocha' 'Northlands'
#  'Anzoategui' 'Cook Islands' 'Tamil Nadu' 'Pearl Islands' 'Taveuni'
#  'Johnston Atoll' 'Baatan' 'Rio De Janeiro' 'Nueva Esparta'
#  'North Pacific Coast' 'Caroline Islands' 'Cheshire'
#  'Louisiade Archipelago'
#  'Kwazulu-Natal Between Port Edward And Port St Johns'
#  'Milne Bay Province' 'Cikobia Island (North Of Vanua Levu)'
#  'Rayong Province' 'Zamboanga Del Sur Province' 'Rio Grande De Norte'
#  'Off The Western Coast Of Peninsular Malaysia' 'New Brunswick'
#  'Miyako Island' 'Alaska' 'Minerva Reef' 'Madang Province'
#  'Worcestershire' 'Alinglaplap Atoll' 'Adriatic Sea' 'Ralik Chain'
#  'Grand Baie' "L' Etang Salé-Les-Bains" 'Southern Japan'
#  'Cap Vert Peninsula' 'Marches Region' 'Berry Islands' 'Transvaal' 'Gaza'
#  "Grand'Anse" 'Beaufonds' 'Miyako' "L'Etang-Sale"
#  'South Sinai, Gulf Of Aqaba' 'Cat Cay' 'Missouri'
#  '12 Miles Off The North Coast' 'Chatham Islands, East Of New  Zealand'
#  'Saint-Denis' 'Vava’U' 'Clearwater Bay' 'New Territories'
#  'Aichi Prefecture' 'Tafea Province' 'Kagoshima Prefecture' 'Saint-Joseph'
#  'Banaadir Region' 'La Libertad' 'Costa Blanca' 'Walkers Cay'
#  'On The Kowloon Penisula, South Of Sai Kung' 'Ehime Prefecture'
#  'Tongapatu Group' 'West Africa' 'Wakaya Island' 'Mexico / Caribbean Sea'
#  'Antarctic Ocean' 'La Saline-Les-Bains' 'Sea Of Japan' 'Tavenui'
#  'Ligurian Sea' "L'Etang-Salé" 'Kowloon Peninsula' 'Port Shelter'
#  'Laucala Island' 'Sainte-Marie' 'Great Exuma Island' 'Sainte-Suzanne'
#  'Tuscany' 'Tyrrhenian Sea' 'New Ireland' 'Valpariso Province'
#  'Viscayan Sea' 'Manfredonia' 'Tokyo Prefecture' 'Saint-Louis' 'Mindoro'
#  'Between Dr And Puerto Rico' 'Between Honiara & Isabel Island'
#  'Florida Straits' 'Gulf Of Lyons' 'Cádiz' 'Sicily' 'Andikira Fokithes'
#  'Central Philippines' 'Northwest Italy' 'English Channel'
#  'North & South Carolina' 'Kumamoto Prefecture' 'Biserta' 'Saint-Philippe'
#  'Chungnam' 'Eronogo Region' 'Coquimbo' 'Pagasitikos Gulf'
#  "St. Mary'S Parish" 'Romblon Province' 'Lamu Archipelago' 'Los Vilos'
#  'Island Of Kos' 'Madeira Islands' 'Ho Ha Wan Marine Park'
#  'Southern Thailand' 'Golfo De Venezia' 'Ralik Archipelago'
#  'South China Sea 200 Miles From Hong Kong' 'Reggio Calabria Province'
#  'Mirs Bay' 'Genoa Province' 'Ganges-Brahmaputra Delta'
#  'Split-Dalmatia County' 'Primorje-Gorski Kotar County' 'Aulong Island'
#  'Western Caroline Islands' 'Antibes' 'Illeginni Atoll' 'Istria County'
#  'Between Beira & Maputo' 'Istria' 'Khuzestan Province' 'Inhambe Province'
#  'Namonuito Atoll' 'Eastern Caroline Islands'
#  'Western Caroline Islands (North Pacific Ocean)' 'Caribbean Sea'
#  'St. Andrew Parish' '200 Nm Southeast Of Manila' 'Limpopo River'
#  'New Ireland Province' 'Zadar County' 'Basrah' 'Clarendon' 'Moro Gulf'
#  'Johor' 'Magdalena Department' 'Mafia Island' 'Gulf Province'
#  'Morobe Province' 'Limón Province' 'Rombion Province' 'Veracruz'
#  'Brindisi Province' 'Kagawa Prefecture' 'Liguria' 'Hamilton'
#  'Out Islands' 'Mugla Province' 'Gibraltar' 'New Britain' 'Bay Of Maputo'
#  'Duke Of York Islands' 'Taranto Province' 'Northern Taiwan'
#  'Admiralty Islands, Manus Province' 'North Sumatra'
#  "250 Miles Southwest Of O'Ahu, Hawaii" 'West Coast' 'East Sepik'
#  'Near Bougainville (North Solomons)' 'East Of The Gulf Of Aqaba'
#  'Bougainville (North Solomons)' 'Okayama Prefecture' 'San Blas'
#  'Connecticut' 'Lau Group' 'Caribbean Coast' 'Vita Levu'
#  'San Blas Islands' 'Puntarenas Province' 'Lomaloma, Lau'
#  'Between Southampton & Canary Islands' 'South Coast, East New Britain'
#  'Lau Province' 'Ysabel Island' 'Santo Domingo' 'San Blas Coast'
#  'Thessaly' 'Lomaiviti  Island Group' 'Rodrigues' 'Manus Island'
#  'Pinas Bay' 'Grand Turk Island' 'Off Coast Of West Africa' 'Sharon'
#  'Antalya Province' 'Northern District'
#  'New Ireland Province, Bismarck Archipelago' 'Cyclades' 'Viti Levu'
#  'Off The Coromandel Peninsula, North Island' 'Madang'
#  'Guadalcanal Province' '10ºs, 142ºe' 'Kwajalein Atoll' 'East Flores'
#  'Guerrrero' 'Western Luzon Island' 'Shefa Province'
#  '165  Miles From Bermuda'
#  '25 Km Off The Coast Of Iran & 483Km From Mouth Of Persian Gulf'
#  'Venice Province' 'Sandaun Province' 'Anatolia'
#  'East New Britain Province' 'United Arab Emirates'
#  'Wake Island (Enenkio)' '19S, 178?E' 'Pennsylvania' '9.35N 79.35W'
#  'Roncador Bank' 'Western District' 'Enroute From Suez To Aden (Yemen)'
#  '180 Miles Southeast Of Okinawa' 'Eniwetok Atoll' 'Cap-Vert Peninsula'
#  'Delagoa Bay' 'In The English Channel' 'Cook Strait'
#  'Unknown, Treated At Wick, Scotland' 'Corregidor Island' 'Paget'
#  '33N, 68W' 'Casamance' 'Madang (Wo)' 'Between Timor & Darwin, Australia'
#  'Pacific Coast' 'St. Georges' 'Eastern  Province'
#  'Northwest Of Viti Levu' 'West New Britain Province' 'Rigo Subdistrict'
#  'Masbate' '400 Miles Southeast Of Sri Lanka' 'Lomaiviti Province'
#  'Kadavu' 'Leyte Island' 'Orissa' 'Hokkaido Prefecture' 'North Palawan'
#  'Queaon' 'Panama' 'In The Gulf Stream' 'Mersin Province' 'Guyamas'
#  'Between England & South Africa' 'Mindanao' 'Kikori River Mouth'
#  'South Chungcheong Province' 'Ahirkapi Coast' 'Tutuila Island'
#  'Between Hawaii & Wake Island' 'Taipei Hsien' 'Ibaraki Prefecture'
#  'South Pacific Ocean' 'Canal Zone' '1,000 Miles East Of Hawaii' 'Honiara'
#  'Yucatan Channel' 'Havana Province' 'Karun River'
#  'Abau Subdistrict,Central Province' 'New Britain, Bismarck Archipelago'
#  'Estuaire Province' 'Near Dakar, Cap Vert Peninsula'
#  'Near The Andaman & Nicobar Islands' 'Mozambique Channel' 'Tyrrenian Sea'
#  'Congreve Channel' 'St. Thomas Bay' 'Madeira'
#  'Between Comores & Madagascar' 'Corfu Island' '1000 Miles West Of Hawaii'
#  'Izo Islands' 'Open Sea' 'Aden' 'New Ireland, Bismarck Archipelago'
#  '18S / 50E' 'Illinois' 'Isles Del Rosario' 'Wake Island' 'Isle Of Man'
#  'Nagasaki Prefecture' 'Liguaria' 'Slovenia' 'South Shore'
#  'Buenos Aires Province' '330 To 350 Miles East Of Wake Island'
#  'Gulf Of Panama' 'Genoa  Province' 'Abau Sub District, Central Province'
#  'Teramo' 'Red Sea State' 'Curacao' 'Port Louis Province' 'Montserrado'
#  'Bay Of Maputu' 'Sofala Province' 'Salerno' 'Salerno Province' 'Taranto'
#  'Naples Province' 'Sago Prefecture' 'Savona' 'Southern Province'
#  'Jakarta Harbour' 'Singapore Harbor' 'Calabria' 'Shatt-El-Arab River'
#  'Shatt-Al-Arab River' 'Calvados Archipelago' 'Shat-Al-Arab River'
#  'Between Kwajalein Atoll & Johnston Island' 'Attica' 'Adana Province'
#  'Bandar Ma’Shur Sea Inlet' 'Saipan' 'Carpathian Sea' 'Kwajalein'
#  'Dar-Es-Salaam' '"Head Of The Gulf"' 'Ryukyu'
#  'In Transit Between Tinian And Leyte' 'Northern Java' 'Tel Aviv'
#  'Colon Province' '300 Miles East Of Luzon'
#  'Bernardino Strait Near Gulf Of Leyte'
#  'Off Samar Island In The Gulf Of Leyte' 'Lake Nicaragua (Fresh Water)'
#  'Pacific Ocean' 'Near The Fiji Islands' '40 Miles South Of Naples'
#  'Northwest Of Papua New Guinea' 'Between Hawaii And U.S.A.'
#  'Off South American Coast' 'Makora-Ulawa Province' '04.05N-13.23W'
#  'Midway Atoll' '300 Miles East Of St. Thomas (Virgin Islands)'
#  'West Of Ceylon (Sri  Lanka)' 'East Java' 'Camiguin Island'
#  'Cay Sal Bank' '(Southwestern Pacific)' 'Panama City' 'Off Libya'
#  'North Of Pernambuco, Brazil' 'Off Coast Of Ecuador' 'Trelawney Province'
#  'In Convoy Ob 274' 'New Georgia' 'Panama Bay (Pacific Ocean)' 'Bwagaoia'
#  'Western Papuan Gulf' 'Carabobo' 'Ascension Bay' 'North China'
#  'Lower San Juan River' 'Nicoya Peninsula' 'Basrah City' 'West Bengal'
#  'Argyllshire' 'Arran' 'Argyll' 'Fishing Grounds' 'Newfoundland'
#  'Isle Of Wight' 'Makira-Uluwa Province' 'Northern (Oro) Province'
#  'Herzliyah' 'Elqui Province' 'Istanbul' 'St Michael Parish'
#  'Barlavento Islands' 'Viti Levu Island' 'Bay Of Fundy' 'Manila'
#  'French Southern Territories' 'Niua' 'Black River' 'Phoenix Islands'
#  'Cienfuegos Province' 'Santiago Island' 'Near Puntarenas' 'Porto Seguro'
#  'Salinas Bay' 'Golfo Di Genova In The Ligurian Sea' 'Sants-Montjic'
#  'South Of The Equator' 'Bay Of Monaco' 'Vancouver'
#  '2 To 3 Miles Off Taboguilla Island, Pacific Ocean' 'Dorset'
#  '150 Miles Offshore' 'Galica' 'Demerara County' 'Vera Cruz' 'Manila Bay'
#  'Lucy' 'East Yorkshire' 'Cavite Province, Luzon' 'Cape Haitien' 'Leyte'
#  'Halifax' 'Turtle Bogue'
#  '60 Miles North Of San Domingo In The West Indies' 'Colon' 'Off Ireland'
#  'Mediterranean Sea' 'Gran Canaria' 'Apolima Strait' 'Essequibo' 'Lagos'
#  'Trieste' '5Aint-Denis' 'Viti Levu Group' 'Balearics' 'Málaga'
#  'Georges Bank' 'Zambesi River' 'Colón Province' '30 Nm From Singapore'
#  'Andalucia' 'Sfax' 'South Atlantic Ocean' 'Galicia' 'Gulf Of Suez' 'Java'
#  'Tiburon Peninsula' 'Oaxaca' 'Harare Province' 'Khánh Hòa Province'
#  'Maluku Province' 'Suez Canal' 'Nusa Tenggara' 'Between Noumea & Sydney'
#  'Villa Clara Province' 'Ancona Province' 'Quezon' 'Rio San Juan'
#  'Southern Cyprus' 'Syracuse' 'Western Viscayas' 'Mindoro Occidental'
#  'Negros' 'Imperia Province' 'Muala' 'East Coast' 'Ratak'
#  'Socotra Islands' 'Off Cape Haitien' 'Moluccas' 'Bocas Del Toro'
#  'Provence' 'Bay Of Campeche' 'Rangoon' 'Bay Of Bengal' 'Bayelsa State'
#  'South Island?' 'Norfolk Island' 'Brittany' 'Line Islands'
#  'Woodlark Islands' 'Munxar Reef' 'Northern Peloponnese'
#  'Between Perth & Colombo' 'Gujarat' 'Lukovo' 'Cortés'
#  'Somewhere Between Philadelphia And Hiogo, Japan' "Côte D'Azur"
#  'Maldonado Coast' 'Western Banks' 'Andaman Islands'
#  'Off The Coast Of West Africa' 'Misamis Oriental' 'Strait Of Messina'
#  'Hoogly River' 'Cyclades Archipelago' 'Mount Lebanon'
#  'Between Hastings & Fairlight, Sussex' 'Gilbert Islands'
#  'Lomaiviti Provine' 'Off The Coast Of South America' '22ºn, 88ºe'
#  'Matanzas Province (North Coast)' 'Alpes Maritime' 'Edinburgh'
#  'Eastern Catalona' '300 Miles East Of Mauritius' 'Foveaux Strait'
#  'Sumatra' 'Conakry Region' 'Corfu' 'Malaga' 'Bonin Islands'
#  'Fernando Po Island' 'Mangaia Island' 'Between Australia & Usa'
#  'Tongatapu' 'Norfolk' 'Island Of St. Thomas' 'Cumberland'
#  'Sanma Province' "35º39 : 165º8'" 'Cuba' 'Paraiba' 'Cape Coast'
#  'Rivers State' 'St. Anne' 'St Helena' 'Skagerrak Arm Of The North Sea'
#  'Las Perlas Archipelago' 'Bardestrand' 'Southwest Coast' 'Quebec'
#  'Kerala' 'Nice & Marseilles' 'Magarita Or Cubagua Islands' 'Yucatan'
#  'Ionian Sea' 'Piraeus' 'Off Thessaly' 'Paloma' 'Bocas Del Toro Province'
#  'Gulf Of Tadjoura' 'Cyrenaica' 'Northern Province' 'Los Roques  Islands'
#  'Dodecanese Islands' 'Malaita Province' 'South Korea'
#  'Milne Bay  Province' 'Island Of Volos' 'Amirante Islands'
#  'Kadavu Island Group' 'Toamasina Province' 'Riau Province' 'Bikini Atoll'
#  'Between New Ireland & New Britain' 'Ba Ria-Vung Tau  Province'
#  'Moala Island']
#
# Unique values in column 'location':
# ['Bargara Beach' "Old Man'S, Waikiki" 'Rainbows, Oahu' ...
#  'Ocracoke Inlet' 'Panama Bay 8ºn, 79ºw'
#  'Below The English Fort, Trincomalee']
#
# Unique values in column 'activity':
# ['Swimming' 'Surfing' 'UNKNOWN' ...
#  'Crew Swimming Alongside Their Anchored Ship' '4 Men Were Bathing'
#  'Wreck Of  Large Double Sailing Canoe']
#
# Unique values in column 'name':
# ['Brooklyn Sauer' 'Matthew White' 'Unknown' ... 'A "Chiefess"' 'Ahmun'
#  'Jules Patterson']
#
# Unique values in column 'sex':
# ['f' 'm']
#
# Unique values in column 'age':
# [13 28 11 46 32 29 10 64 62 39 22 15 16 21 66 52 20 44 26 47 55 30 59  8
#  50 45 34 38 37  9 19 35 65 77 60 49 42 24 73 25 18 58 67 17 14  6 41 53
#  68 43 40 51 31 33 56 12 36 27 57  7 71 48 54 75 61 70 23  4 63 74 69  3
#  82 72  5 86 84 87  1 81 78]
#
# Unique values in column 'injury':
# ['minor injuries to back, abdomen and legs'
#  'no injury, shark bit surfboard' 'lacerations to left foot' ...
#  'fatal, leg stripped of flesh'
#  'fatal, knocked overboard by tail of shark & carried off by shark'
#  'fatal. "shark bit him in half, carrying away the lower extremities"']
#
# Unique values in column 'time':
# ['16h00' nan '13h30' '11h30' '06h30' '20h00' '13h00' '11h12' '16h30'
#  '15h00' '02h00' '09h15' 'early morning' '16h32' '11h00' 'morning' '10h30'
#  '13h20' '14h00' '09h00' '10h20' '15h05' '17h00' '15h45' '07h45' '10h40'
#  '07h50' '01h00' '10h00' 'afternoon' '19h30' 'evening' '17h50' '09h30'
#  '15h30' '08h45' '"midday"' '16h25' '13h55' '13h50' '17h20' '13h45'
#  '10h10' '14h35' 'night' '19h15' '11h20' '07h15' '07h00' '18h00' '12h30'
#  '08h00' '14h20' '17h30' '07h20' '14h50' '-16h30' '12h00' '17h17' '11h15'
#  '19h00' '07h53' '16h10' '11h17' '17h45' '10jh45' 'early  morning' '13h12'
#  '07h30' '11hoo' '11h43' '10h15' '14h09' '12h15' '19h12' '15h20' '16h40'
#  '11h24' '12h50' '07h31' '14h45' '19h20' 'dusk' '11h45' '06h40' '`17h00'
#  '07h51' '11h46' '20h30' '12h23' '07h07' '16h39' '15h57' '14h30' '16h45'
#  '10j30' '08h15' '08h56' '15h40' '18h30' '07h58' '17h40' '09h00-10h00'
#  '17h10' '09h36' '08h40' '06h00' 'sunset' '10h45' 1415 '14h00-15h00'
#  '14h15' '09h08' '15h59' '08h30' '12h20' '10h50' 'midday' '09h40' '14h33'
#  '12h58' '"evening"' '16h15' '23h00' '06h50' '12h45' '11h55' '22h20'
#  '08h48' '16h21' '16h26' '18h45' '03h00' '13h40' '06h15' 'before 10h00'
#  '06h45' 'early afternoon' '06h55' '13h42' '13h15' '09h29' '10h47' '14h11'
#  '15h35' '14h40' '14h00  -15h00' 'late afternoon' '16h50' '21h50' '17h35'
#  '19h00, dusk' '15h01' '23h30' '10h44' '13h19' 'shortly before 12h00'
#  '17h34' '08h50' '09h50' '9h00' '10h43' 'after noon' '15h15' '19h05' 1300
#  '14h30 / 15h30' '22h00' '16h20' '14h34' '15h25' '14h55' '17h46'
#  'morning ' '15h49' 'midnight' '09h30 / 10h00' '18h15' '04h00' '10h25'
#  '10h45-11h15' '15h52' '19h45' '12h10' '18h05' '11h41' '12h25' '17h51'
#  '16h12' '09h45' '05h00' '03h30' 'sometime between 06h00 & 08hoo' '16h18'
#  '11h10' '07h00 - 08h00' '18h15-18h30' '17h01' '09h57' '08h20' '17h58'
#  '15h19' '10h55' '15h55' '12h40' '16h05' '14h10' '13h24' '09h00 - 09h30'
#  '0830' '11h40' '08h10' '15h56' 'just before noon' '07h56' '1600' '16h35'
#  '09h05' '19h28' '12h38' '05h50' '15h50' '11h05' 'dawn' '05h45' '13h25'
#  '13h26' '09h11' '18h20' 'am' '13h51' 'a.m.' '08h05' '10h35' '15h44'
#  '21h00' 'lunchtime' '15j45' '09h35' '10h27' '10h16' '0500' 'before 07h00'
#  '09h20' '10h00 -- 11h00' '12h05' '14h21' '18h50' '15h53'
#  '"just before 11h00"' '11h115' '20h15' '12h39' '07h05' '  ' '13h05' 'n'
#  '11h50' 'just before sundown' '17h55' '22h30' '17h15' '11h30 ' '06h10'
#  'between 05h00 and 08h00' '07h08' '17h00 or 17h40' '>08h00' '--' '12h02'
#  '12h55' '16h14' '17h11' '00h30' '14h37' '10h07' '13h53' '13h23'
#  'just after 12h00' '02h30' '11h56' ' ' 'shortly after midnight' '14h25'
#  '13h345' '\xa0 ' '06h47' '09h00 -10h00' '20h45 (sunset)' 'late morning'
#  'p.m.' '18h40' '13h14' '13h06' 'shortly before 13h00' '12h34' '11h53'
#  '8:04 pm' '12h46' '12h48' '17h42' '12h35'
#  'possibly same incident as 2000.08.21' 'after dusk' '11h57' 'noon'
#  '11h25' '18h25' '10h28' '14h16' '09h55' '2 hours after opperman' '09h30 '
#  'mid afternoon' 'mid morning' '11h48' '11h00 / 11h30' '07h19' '13h37'
#  '11h06' '"night"' '18h30?' '11h58' '11h51' '18h12' '07h10' '07h40'
#  '12h33' '30 minutes after 1992.07.08.a' '>06h45' '15h06' '12h54'
#  'between 06h00 & 07h20' '16h55' '05h40' '<07h30' '21h30' '17h00 sunset'
#  'nightfall' 'x' '08h57' '18h30 (sunset)' '06j00' '08h35' '10h22' '02h45'
#  'prior to 10h37' 'daybreak' '18h10' '>12h00' 'mid-morning' '08h55'
#  '16h30 or 18h00' 'just before dawn' ' 14h00' 'daytime' 'dark'
#  '10h00 / 11h00' '"after lunch"' '07h32' '15h00 or 15h45' '>17h00'
#  '19h00 / 20h00' '12h45 / 13h45' '14h00 - 15h00' '03h45 - 04h00' '13h10'
#  '09h30 / 15h30' '08h00 / 09h30' '19h35' '12h00 to 14h00' '13h35'
#  'late night' '01h32' '10h30 or 13h30' '16h23' '15h00j' 'midday.'
#  '"after dark"' '10h00 or 14h00' '19h10' '2 hrs before sunset'
#  '18h15 to 21h30' 1500 '"shortly before dusk"' '>17h30' '>14h30'
#  'between 11h00 & 12h00' 'after 04h00' '11h01 -time of ship sinking'
#  'ship aban-doned at 03h10' '19h55'
#  'fatal  (wire netting installed at local beaches after this incident.)'
#  '01h30' 'after midnight' 'late afternon' '05h30' '08h58'
#  '"early evening"' '   ' 'before daybreak' 'before 10h30' '06h00 -- 07h00'
#  '01h50' '17h00-18h00' '19h00-20h00']
#
# Unique values in column 'species':
# ['tiger shark' "tiger shark 8'" "3' to 4' shark" ... "12' tiger shark"
#  'blue pointers'
#  'said to involve a grey nurse shark that leapt out of the water and  seized the boy but species identification is questionable']
#
# Unique values in column 'source':
# ['yahoo news, 3/15/2024' 'surfer, 3/6/2024f' 'hawaii news now, 3/4/2024'
#  ... 'h. taunton; n. bartlett,  pp. 233-234' 'the sun, 10/20/1938'
#  's.w. baker']

# %%
sharkattacks.to_csv('https://drive.google.com/drive/my-drive/sharkattacks_clean.csv', index=False)

# %%
fishers = sharkattacks.groupby('activity')
fishers = fishers.get_group('Fishing')
fishers.head(10)
# Out:
#             date  year        type       country                  state  \
# 4    14 feb-2024  2024  unprovoked         INDIA            Maharashtra
# 5    04-feb-2024  2024    provoked      TRINIDAD                    Nan
# 9    05-jan-2024  2024    provoked  SOUTH AFRICA  Eastern Cape Province
# 25   03 nov-2023  2023  unprovoked     AUSTRALIA      Westerm Australia
# 30   23 oct-2023  2023    provoked        MEXICO           Quintana Roo
# 31   21 oct-2023  2023  watercraft     AUSTRALIA      Western Australia
# 42  09 sep- 2023  2023  unprovoked   PHILIPPINES                Bolinao
# 48   22 aug-2023  2023  watercraft           USA             California
# 51   16 aug-2023  2023    provoked      PORTUGAL                  Norte
# 55   30 jul-2023  2023  unprovoked           USA                Florida
#
#                                   location activity                 name sex  \
# 4         Vaitarna River, Palghar District  Fishing  Vicky Suresh Govari   m
# 5                                  Unknown  Fishing                 Male   m
# 9                            Papiesfontein  Fishing                 Male   m
# 25                             Peak Island  Fishing                 Male   m
# 30      Banco Chinchorro Biosphere Reserve  Fishing                 Male   m
# 31                Alexander Bay, Esperance  Fishing  Inflatatable Dinghy   m
# 42  Pangasinan, Ilocos Norte, Luzon Island  Fishing                 Male   m
# 48          Pebble Beach, San Mateo County  Fishing                 Male   m
# 51                 9 Nm Off Vila Do Conde   Fishing                 Male   m
# 55       Anna Maria Island, Manatee County  Fishing                 Male   m
#
#     age                                             injury   time  \
# 4    32                     calf of lower left leg injured    NaN
# 5    28                                    shoulder bitten  06h30
# 9    62  provoked incident. lacerations and puncture wo...    NaN
# 25   28                                       minor injury  14h00
# 30   59                                  both arms injured    NaN
# 31   28  dinghy damaged by shark. no injurty to the 5 m...  17h00
# 42   28                           laceration to left thigh    NaN
# 48   19             shark bit kayak, no injury to occupant  13h00
# 51   28                                         leg bitten  19h30
# 55   22                                   lower leg bitten  15h30
#
#                 species                         source
# 4        bull shark, 7'      times of india, 2/14/2024
# 5   blacktip reef shark   trinidad guardian, 2/11/2014
# 9     raggedtooth shark        jacaranda fm. 12/6/2024
# 25          lemon shark          daily mail, 11/3/2023
# 30                  NaN       tyt newsroom. 10/26/2023
# 31    bronze whaler, 6'                abc. 10/22/2023
# 42                  NaN    manila bulletin, 9 /10/2023
# 48                  NaN                 msn, 8/22/2023
# 51           blue shark  portugese resident, 8/17/2023
# 55                  NaN             r. babington, gsaf

# %%
other_fishers = pd.DataFrame(fishers['country'])
other_fishers.value_counts()
other_fishers_vc = other_fishers['country'].value_counts().reset_index()
sexta_feira = other_fishers_vc[other_fishers_vc["count"]>50]
sexta_feira
# Out:
#             country  count
# 0               USA    364
# 1         AUSTRALIA    301
# 2      SOUTH AFRICA    144
# 3  PAPUA NEW GUINEA     57
# 4           BAHAMAS     55

# %%
sexta_feira.replace({'PAPUA NEW GUINEA': 'P.N. GUINEA', 'SOUTH AFRICA':'S. AFRICA'}, inplace=True)
# Out:
# <ipython-input-58-58fa1a1aa126>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sexta_feira.replace({'PAPUA NEW GUINEA': 'P.N. GUINEA', 'SOUTH AFRICA':'S. AFRICA'}, inplace=True)

# %%
import matplotlib as plt

plt.pyplot.bar(x='country',height='count', width=0.5, align= 'center', data=sexta_feira)
# Out:
# <BarContainer object of 5 artists>

# %%
sexta_feira.loc[0][1]
# Out:
# 364

# %%
(sexta_feira.loc[0][1]/sexta_feira['count'].sum())*100
# Out:
# 39.52225841476656

# %%
from matplotlib import pyplot as plt
_df_21['count'].plot(kind='line', figsize=(8, 4), title='count')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
sex = fishers.groupby(['sex'])['sex'].agg(['count'])

# %%
from matplotlib import pyplot as plt
_df_19['count'].plot(kind='line', figsize=(8, 4), title='count')
plt.gca().spines[['top', 'right']].set_visible(False)
